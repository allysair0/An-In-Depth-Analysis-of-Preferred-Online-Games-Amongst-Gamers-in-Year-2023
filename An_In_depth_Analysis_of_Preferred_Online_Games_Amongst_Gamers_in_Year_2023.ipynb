# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sample_data/survey.csv')

df.head()
# Out:
#              Timestamp       Age             Gender               Location  \
# 0  07/12/2023 19:33:29     18-24               Male      Sta. Cruz, Laguna
# 1  07/12/2023 19:37:15     18-24             Female      Nagcarlan Laguna
# 2  07/12/2023 19:39:43     18-24  Prefer not to say  gatid sta cruz laguna
# 3  07/12/2023 19:41:04  Under 18             Female                 Laguna
# 4  07/12/2023 19:45:55     18-24               Male           Philippines
#
#     Gaming Platform Gaming Frequency Average Hours Spent per Week  \
# 0  PC, Mobile Phone            Daily                  10-20 Hours
# 1      Mobile Phone           Weekly                   5-10 Hours
# 2  PC, Mobile Phone           Weekly                   5-10 Hours
# 3      Mobile Phone            Daily                   5-10 Hours
# 4      Mobile Phone            Daily                   5-10 Hours
#
#                Preferred Gaming Time           Favorite Game(s) at the Moment  \
# ...

# %%
sns.countplot(x='Age', data=df)
plt.title('Age Group')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Gender')
plt.show()

# %%
_df_15.groupby('Location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(12, 5))
sns.countplot(x='Gaming Platform', data=df)
plt.title('Gaming Platform')
plt.xlabel('Response')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Gaming Frequency'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Gaming Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Average Hours Spent per Week'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Average Hours Spent per Week')
plt.show()

# %%
plt.figure(figsize=(17, 5))
sns.countplot(x='Preferred Gaming Time', data=df)
plt.title('Preferred Gaming Time')
plt.xlabel('Response')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(17, 5))
sns.countplot(x='Favorite Game(s) at the Moment', data=df)
plt.title('Favorite Game(s) at the Moment')
plt.xlabel('Response')
plt.ylabel('count')
plt.show()
